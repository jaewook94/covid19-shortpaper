# %%
from tensorflow.keras.layers import Dense, Input, MaxPooling2D, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import resnet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras

# %%
batch_size = 64
width, height, channel = 400, 400, 3
epochs = 30
input_shape = (width, height, channel)

# %%
# pretrained된 VGG16모델을 가져온다.
# https://keras.io/api/applications/vgg/#vgg16-function
pretrained_model = tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=input_shape,
    pooling=None
)

# %%
pretrained_model.trainable = False    # VGG16의 가중치들은 학습이 이루어지지 않도록 한다

model = Sequential()

# CAM을 위해 하단에 다른 레이어를 추가해야하기 때문에 VGG16의 맨 마지막 레이어(pooling layer)를 제외하고 나머지 레이어를 model에 추가해준다
for layer in pretrained_model.layers[:-1]:
    model.add(layer)

# CAM을 구현하기 위해 Conv2D, GlobalAveragePolling2D, Dense 레이어를 추가해준다
model.add(tf.keras.layers.Conv2D(filters=1024, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dense(2, activation='softmax'))

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

metrics = [keras.metrics.TruePositives(name='tp'),
           keras.metrics.FalsePositives(name='fp'),
           keras.metrics.TrueNegatives(name='tn'),
           keras.metrics.FalseNegatives(name='fn'),
           keras.metrics.BinaryAccuracy(name='accuracy'),
           keras.metrics.Precision(name='precision'),
           keras.metrics.Recall(name='recall'),
           keras.metrics.AUC(name='auc')]

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=metrics)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 400, 400, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 400, 400, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 200, 200, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 200, 200, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 200, 200, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 100, 100, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 100, 100, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 100, 100, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 100, 100, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 50, 50, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 50, 50, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 50, 50, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 50, 50, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 25, 25, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# conv2d (Conv2D)              (None, 25, 25, 1024)      4719616
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 2050
# =================================================================
# Total params: 19,436,354
# Trainable params: 4,721,666
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# 데이터 가져오기
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.25)
train_generator = datagen.flow_from_directory('preprocessed_data/train',
                                                    target_size=(400, 400),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    subset='training')

valid_generator = datagen.flow_from_directory('preprocessed_data/train',
                                                    target_size=(400, 400),
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    subset='validation')

test_generator = datagen.flow_from_directory('preprocessed_data/test',
                                                    target_size=(400, 400),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

history = model.fit(
        train_generator,
        steps_per_epoch = train_generator.samples // batch_size,
        validation_data = valid_generator, 
        validation_steps = valid_generator.samples // batch_size,
        epochs = epochs,
        callbacks=[callback])
# Out:
# Found 1953 images belonging to 2 classes.
# Found 650 images belonging to 2 classes.
# Found 650 images belonging to 2 classes.
# Epoch 1/30
# 30/30 [==============================] - 24s 811ms/step - loss: 0.7846 - tp: 1149.0000 - fp: 740.0000 - tn: 1149.0000 - fn: 740.0000 - accuracy: 0.6083 - precision: 0.6083 - recall: 0.6083 - auc: 0.6332 - val_loss: 0.5552 - val_tp: 463.0000 - val_fp: 177.0000 - val_tn: 463.0000 - val_fn: 177.0000 - val_accuracy: 0.7234 - val_precision: 0.7234 - val_recall: 0.7234 - val_auc: 0.8007
# Epoch 2/30
# 30/30 [==============================] - 23s 759ms/step - loss: 0.4956 - tp: 1530.0000 - fp: 390.0000 - tn: 1530.0000 - fn: 390.0000 - accuracy: 0.7969 - precision: 0.7969 - recall: 0.7969 - auc: 0.8660 - val_loss: 0.5193 - val_tp: 451.0000 - val_fp: 189.0000 - val_tn: 451.0000 - val_fn: 189.0000 - val_accuracy: 0.7047 - val_precision: 0.7047 - val_recall: 0.7047 - val_auc: 0.8105
# Epoch 3/30
# 30/30 [==============================] - 23s 761ms/step - loss: 0.4726 - tp: 1439.0000 - fp: 450.0000 - tn: 1439.0000 - fn: 450.0000 - accuracy: 0.7618 - precision: 0.7618 - recall: 0.7618 - auc: 0.8549 - val_loss: 0.4256 - val_tp: 515.0000 - val_fp: 125.0000 - val_tn: 515.0000 - val_fn: 125.0000 - val_accuracy: 0.8047 - val_precision: 0.8047 - val_recall: 0.8047 - val_auc: 0.8932
# Epoch 4/30
# 30/30 [==============================] - 23s 769ms/step - loss: 0.4128 - tp: 1516.0000 - fp: 373.0000 - tn: 1516.0000 - fn: 373.0000 - accuracy: 0.8025 - precision: 0.8025 - recall: 0.8025 - auc: 0.8973 - val_loss: 0.4228 - val_tp: 523.0000 - val_fp: 117.0000 - val_tn: 523.0000 - val_fn: 117.0000 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.8984
# Epoch 5/30
# 30/30 [==============================] - 23s 771ms/step - loss: 0.3794 - tp: 1578.0000 - fp: 311.0000 - tn: 1578.0000 - fn: 311.0000 - accuracy: 0.8354 - precision: 0.8354 - recall: 0.8354 - auc: 0.9144 - val_loss: 0.3783 - val_tp: 532.0000 - val_fp: 108.0000 - val_tn: 532.0000 - val_fn: 108.0000 - val_accuracy: 0.8313 - val_precision: 0.8313 - val_recall: 0.8313 - val_auc: 0.9123
# Epoch 6/30
# 30/30 [==============================] - 23s 755ms/step - loss: 0.3515 - tp: 1598.0000 - fp: 291.0000 - tn: 1598.0000 - fn: 291.0000 - accuracy: 0.8460 - precision: 0.8460 - recall: 0.8460 - auc: 0.9284 - val_loss: 0.3441 - val_tp: 556.0000 - val_fp: 84.0000 - val_tn: 556.0000 - val_fn: 84.0000 - val_accuracy: 0.8687 - val_precision: 0.8687 - val_recall: 0.8687 - val_auc: 0.9329
# Epoch 7/30
# 30/30 [==============================] - 23s 752ms/step - loss: 0.3412 - tp: 1601.0000 - fp: 288.0000 - tn: 1601.0000 - fn: 288.0000 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9301 - val_loss: 0.3832 - val_tp: 518.0000 - val_fp: 122.0000 - val_tn: 518.0000 - val_fn: 122.0000 - val_accuracy: 0.8094 - val_precision: 0.8094 - val_recall: 0.8094 - val_auc: 0.9093
# Epoch 8/30
# 30/30 [==============================] - 23s 751ms/step - loss: 0.3280 - tp: 1613.0000 - fp: 276.0000 - tn: 1613.0000 - fn: 276.0000 - accuracy: 0.8539 - precision: 0.8539 - recall: 0.8539 - auc: 0.9356 - val_loss: 0.3359 - val_tp: 538.0000 - val_fp: 102.0000 - val_tn: 538.0000 - val_fn: 102.0000 - val_accuracy: 0.8406 - val_precision: 0.8406 - val_recall: 0.8406 - val_auc: 0.9299
# Epoch 9/30
# 30/30 [==============================] - 23s 762ms/step - loss: 0.3116 - tp: 1624.0000 - fp: 265.0000 - tn: 1624.0000 - fn: 265.0000 - accuracy: 0.8597 - precision: 0.8597 - recall: 0.8597 - auc: 0.9419 - val_loss: 0.2945 - val_tp: 558.0000 - val_fp: 82.0000 - val_tn: 558.0000 - val_fn: 82.0000 - val_accuracy: 0.8719 - val_precision: 0.8719 - val_recall: 0.8719 - val_auc: 0.9533
# Epoch 10/30
# 30/30 [==============================] - 22s 745ms/step - loss: 0.2985 - tp: 1641.0000 - fp: 248.0000 - tn: 1641.0000 - fn: 248.0000 - accuracy: 0.8687 - precision: 0.8687 - recall: 0.8687 - auc: 0.9468 - val_loss: 0.2950 - val_tp: 561.0000 - val_fp: 79.0000 - val_tn: 561.0000 - val_fn: 79.0000 - val_accuracy: 0.8766 - val_precision: 0.8766 - val_recall: 0.8766 - val_auc: 0.9476
# Epoch 11/30
# 30/30 [==============================] - 22s 744ms/step - loss: 0.3387 - tp: 1598.0000 - fp: 291.0000 - tn: 1598.0000 - fn: 291.0000 - accuracy: 0.8460 - precision: 0.8460 - recall: 0.8460 - auc: 0.9281 - val_loss: 0.3342 - val_tp: 539.0000 - val_fp: 101.0000 - val_tn: 539.0000 - val_fn: 101.0000 - val_accuracy: 0.8422 - val_precision: 0.8422 - val_recall: 0.8422 - val_auc: 0.9322
# Epoch 12/30
# 30/30 [==============================] - 23s 756ms/step - loss: 0.2848 - tp: 1654.0000 - fp: 235.0000 - tn: 1654.0000 - fn: 235.0000 - accuracy: 0.8756 - precision: 0.8756 - recall: 0.8756 - auc: 0.9529 - val_loss: 0.2500 - val_tp: 575.0000 - val_fp: 65.0000 - val_tn: 575.0000 - val_fn: 65.0000 - val_accuracy: 0.8984 - val_precision: 0.8984 - val_recall: 0.8984 - val_auc: 0.9676
# Epoch 13/30
# 30/30 [==============================] - 23s 767ms/step - loss: 0.2906 - tp: 1647.0000 - fp: 242.0000 - tn: 1647.0000 - fn: 242.0000 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9483 - val_loss: 0.2517 - val_tp: 578.0000 - val_fp: 62.0000 - val_tn: 578.0000 - val_fn: 62.0000 - val_accuracy: 0.9031 - val_precision: 0.9031 - val_recall: 0.9031 - val_auc: 0.9690
# Epoch 14/30
# 30/30 [==============================] - 23s 759ms/step - loss: 0.2844 - tp: 1648.0000 - fp: 241.0000 - tn: 1648.0000 - fn: 241.0000 - accuracy: 0.8724 - precision: 0.8724 - recall: 0.8724 - auc: 0.9509 - val_loss: 0.2533 - val_tp: 575.0000 - val_fp: 65.0000 - val_tn: 575.0000 - val_fn: 65.0000 - val_accuracy: 0.8984 - val_precision: 0.8984 - val_recall: 0.8984 - val_auc: 0.9666
# Epoch 15/30
# 30/30 [==============================] - 23s 754ms/step - loss: 0.2509 - tp: 1686.0000 - fp: 203.0000 - tn: 1686.0000 - fn: 203.0000 - accuracy: 0.8925 - precision: 0.8925 - recall: 0.8925 - auc: 0.9639 - val_loss: 0.2429 - val_tp: 578.0000 - val_fp: 62.0000 - val_tn: 578.0000 - val_fn: 62.0000 - val_accuracy: 0.9031 - val_precision: 0.9031 - val_recall: 0.9031 - val_auc: 0.9683
# Epoch 16/30
# 30/30 [==============================] - 23s 772ms/step - loss: 0.2515 - tp: 1683.0000 - fp: 206.0000 - tn: 1683.0000 - fn: 206.0000 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9623 - val_loss: 0.2666 - val_tp: 566.0000 - val_fp: 74.0000 - val_tn: 566.0000 - val_fn: 74.0000 - val_accuracy: 0.8844 - val_precision: 0.8844 - val_recall: 0.8844 - val_auc: 0.9567
# Epoch 17/30
# 30/30 [==============================] - 22s 748ms/step - loss: 0.2292 - tp: 1711.0000 - fp: 178.0000 - tn: 1711.0000 - fn: 178.0000 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9698 - val_loss: 0.2221 - val_tp: 585.0000 - val_fp: 55.0000 - val_tn: 585.0000 - val_fn: 55.0000 - val_accuracy: 0.9141 - val_precision: 0.9141 - val_recall: 0.9141 - val_auc: 0.9749
# Epoch 18/30
# 30/30 [==============================] - 24s 784ms/step - loss: 0.2186 - tp: 1726.0000 - fp: 163.0000 - tn: 1726.0000 - fn: 163.0000 - accuracy: 0.9137 - precision: 0.9137 - recall: 0.9137 - auc: 0.9732 - val_loss: 0.3516 - val_tp: 519.0000 - val_fp: 121.0000 - val_tn: 519.0000 - val_fn: 121.0000 - val_accuracy: 0.8109 - val_precision: 0.8109 - val_recall: 0.8109 - val_auc: 0.9188
# Epoch 19/30
# 30/30 [==============================] - 23s 755ms/step - loss: 0.2255 - tp: 1714.0000 - fp: 175.0000 - tn: 1714.0000 - fn: 175.0000 - accuracy: 0.9074 - precision: 0.9074 - recall: 0.9074 - auc: 0.9714 - val_loss: 0.2459 - val_tp: 573.0000 - val_fp: 67.0000 - val_tn: 573.0000 - val_fn: 67.0000 - val_accuracy: 0.8953 - val_precision: 0.8953 - val_recall: 0.8953 - val_auc: 0.9635
# Epoch 20/30
# 30/30 [==============================] - 23s 750ms/step - loss: 0.2743 - tp: 1655.0000 - fp: 234.0000 - tn: 1655.0000 - fn: 234.0000 - accuracy: 0.8761 - precision: 0.8761 - recall: 0.8761 - auc: 0.9538 - val_loss: 0.2749 - val_tp: 559.0000 - val_fp: 81.0000 - val_tn: 559.0000 - val_fn: 81.0000 - val_accuracy: 0.8734 - val_precision: 0.8734 - val_recall: 0.8734 - val_auc: 0.9553
# Epoch 21/30
# 30/30 [==============================] - 23s 756ms/step - loss: 0.2158 - tp: 1747.0000 - fp: 173.0000 - tn: 1747.0000 - fn: 173.0000 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9740 - val_loss: 0.1997 - val_tp: 593.0000 - val_fp: 47.0000 - val_tn: 593.0000 - val_fn: 47.0000 - val_accuracy: 0.9266 - val_precision: 0.9266 - val_recall: 0.9266 - val_auc: 0.9762
# Epoch 22/30
# 30/30 [==============================] - 23s 765ms/step - loss: 0.2027 - tp: 1723.0000 - fp: 166.0000 - tn: 1723.0000 - fn: 166.0000 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9761 - val_loss: 0.1796 - val_tp: 601.0000 - val_fp: 39.0000 - val_tn: 601.0000 - val_fn: 39.0000 - val_accuracy: 0.9391 - val_precision: 0.9391 - val_recall: 0.9391 - val_auc: 0.9820
# Epoch 23/30
# 30/30 [==============================] - 23s 767ms/step - loss: 0.2048 - tp: 1732.0000 - fp: 157.0000 - tn: 1732.0000 - fn: 157.0000 - accuracy: 0.9169 - precision: 0.9169 - recall: 0.9169 - auc: 0.9762 - val_loss: 0.1797 - val_tp: 602.0000 - val_fp: 38.0000 - val_tn: 602.0000 - val_fn: 38.0000 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9842
# Epoch 24/30
# 30/30 [==============================] - 22s 747ms/step - loss: 0.2481 - tp: 1679.0000 - fp: 210.0000 - tn: 1679.0000 - fn: 210.0000 - accuracy: 0.8888 - precision: 0.8888 - recall: 0.8888 - auc: 0.9621 - val_loss: 0.2508 - val_tp: 570.0000 - val_fp: 70.0000 - val_tn: 570.0000 - val_fn: 70.0000 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9634
# Epoch 25/30
# 30/30 [==============================] - 22s 749ms/step - loss: 0.1883 - tp: 1756.0000 - fp: 133.0000 - tn: 1756.0000 - fn: 133.0000 - accuracy: 0.9296 - precision: 0.9296 - recall: 0.9296 - auc: 0.9803 - val_loss: 0.1866 - val_tp: 595.0000 - val_fp: 45.0000 - val_tn: 595.0000 - val_fn: 45.0000 - val_accuracy: 0.9297 - val_precision: 0.9297 - val_recall: 0.9297 - val_auc: 0.9786
# Epoch 26/30
# 30/30 [==============================] - 23s 767ms/step - loss: 0.2123 - tp: 1713.0000 - fp: 176.0000 - tn: 1713.0000 - fn: 176.0000 - accuracy: 0.9068 - precision: 0.9068 - recall: 0.9068 - auc: 0.9726 - val_loss: 0.2401 - val_tp: 572.0000 - val_fp: 68.0000 - val_tn: 572.0000 - val_fn: 68.0000 - val_accuracy: 0.8938 - val_precision: 0.8938 - val_recall: 0.8938 - val_auc: 0.9669
# Epoch 27/30
# 30/30 [==============================] - 23s 761ms/step - loss: 0.1694 - tp: 1779.0000 - fp: 110.0000 - tn: 1779.0000 - fn: 110.0000 - accuracy: 0.9418 - precision: 0.9418 - recall: 0.9418 - auc: 0.9858 - val_loss: 0.1599 - val_tp: 611.0000 - val_fp: 29.0000 - val_tn: 611.0000 - val_fn: 29.0000 - val_accuracy: 0.9547 - val_precision: 0.9547 - val_recall: 0.9547 - val_auc: 0.9882
# Epoch 28/30
# 30/30 [==============================] - 23s 764ms/step - loss: 0.1636 - tp: 1777.0000 - fp: 112.0000 - tn: 1777.0000 - fn: 112.0000 - accuracy: 0.9407 - precision: 0.9407 - recall: 0.9407 - auc: 0.9851 - val_loss: 0.1533 - val_tp: 616.0000 - val_fp: 24.0000 - val_tn: 616.0000 - val_fn: 24.0000 - val_accuracy: 0.9625 - val_precision: 0.9625 - val_recall: 0.9625 - val_auc: 0.9909
# Epoch 29/30
# 30/30 [==============================] - 23s 754ms/step - loss: 0.1501 - tp: 1786.0000 - fp: 103.0000 - tn: 1786.0000 - fn: 103.0000 - accuracy: 0.9455 - precision: 0.9455 - recall: 0.9455 - auc: 0.9889 - val_loss: 0.1970 - val_tp: 584.0000 - val_fp: 56.0000 - val_tn: 584.0000 - val_fn: 56.0000 - val_accuracy: 0.9125 - val_precision: 0.9125 - val_recall: 0.9125 - val_auc: 0.9772
# Epoch 30/30
# 30/30 [==============================] - 23s 755ms/step - loss: 0.1782 - tp: 1770.0000 - fp: 119.0000 - tn: 1770.0000 - fn: 119.0000 - accuracy: 0.9370 - precision: 0.9370 - recall: 0.9370 - auc: 0.9815 - val_loss: 0.1609 - val_tp: 603.0000 - val_fp: 37.0000 - val_tn: 603.0000 - val_fn: 37.0000 - val_accuracy: 0.9422 - val_precision: 0.9422 - val_recall: 0.9422 - val_auc: 0.9843

# %%
model.evaluate(test_generator)
# Out:
# 11/11 [==============================] - 6s 514ms/step - loss: 0.1413 - tp: 617.0000 - fp: 33.0000 - tn: 617.0000 - fn: 33.0000 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9881
# [0.14133046567440033,
#  617.0,
#  33.0,
#  617.0,
#  33.0,
#  0.9492307901382446,
#  0.9492307901382446,
#  0.9492307901382446,
#  0.9880923628807068]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# | model | test_precision | test_recall | test_auc | test_accuracy |
# |---|
# | VGG16 | 0.9833 | 0.9219 | 0.9889 | 0.9538 |

# %% [markdown]
# | Hypermeters | Values |
# |---|
# | Epoch | 20 |
# | Batch Size | 64
# | Train Validation Test ratio | 6:2:2 |
# | Optimizer | Adam |
# | Input size | (400, 400, 3) |

# %% [markdown]
# |  |  |
# |---|
# | TP=295 | FN=25 |
# | FP=5 | TN=325 |

# %%
# 참고
# https://dryjelly.tistory.com/147
# https://github.com/jacobgil/keras-cam/blob/master/cam.py

index = 5

import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

get_output = tf.keras.backend.function([model.layers[0].input],
                                       [model.layers[-3].output, model.layers[-1].output])    # 이미지 입력을 받아 model의 마지막에 추가한 Conv2D와 Dense 레이어를 출력하는 모델
[conv_outputs, predictions] = get_output(np.array([test_generator[0][0][index]]))                # 이미지 입력
conv_outputs = conv_outputs[0, :, :, :]

class_weights = model.layers[-1].get_weights()[0]    # model의 맨 마지막 레이어인 Dense 레이어의 weight를 가져온다

cam = np.zeros(dtype = np.float32, shape = conv_outputs.shape[0:2])
for i, w in enumerate(class_weights[:, 1]):
        cam += w * conv_outputs[:, :, i]    # 마지막 레이어의 각 가중치와 Conv2D의 결과를 곱하여 누적하여 가산 -> CAM 구현

# %%
# 결과 이미지를 보기 좋게 가공

# CAM 이미지의 값 범위를 0 부터 255까지로 맞추고
# 이미지 크기를 원본 데이터와 일치하도록 resize한다
heatmap = cam
heatmap = heatmap / (np.max(heatmap) - np.min(heatmap)) * 255.9
heatmap = -heatmap + 256
heatmap = np.uint8(heatmap - np.min(heatmap))
heatmap = cv2.resize(heatmap, (height, width))
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# 원본 이미지도 비슷하게 처리
origin_img = test_generator[0][0][index]
origin_img = origin_img / (np.max(origin_img) - np.min(origin_img)) * 255.9
origin_img = np.uint8(origin_img - np.min(origin_img))
plt.subplot(1, 2, 1)
plt.imshow(origin_img)

# 원본 이미지와 CAM 합성
a = 0.6
dst = cv2.addWeighted(origin_img, a, heatmap, 1 - a, 0)
plt.subplot(1, 2, 2)
plt.imshow(dst)
